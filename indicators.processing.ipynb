# %%
# Standard libraries
import os

# Third-party libraries
import pandas as pd
import xarray as xr

# Local libraries
from utilities import netcdf

# %%
# Paths
DATA_DIR = os.path.join(os.getcwd(), "data/intermediate/hadukgrid/monthly-1km")
OUT_DIR = os.path.join(os.getcwd(), "data/processed/indicator")

# %%
NC_FILES = netcdf.list_files(DATA_DIR, path=True)

# %%
names = {
    "groundfrost": "Frost",
    "sun": "Sun",
    "tas": "Temperature",
    "snowLying": "Snow",
    "tasmax": "Maximum temperature",
    "hurs": "Humidity",
    "rainfall": "Rain",
    "sfcWind": "Wind",
    "tasmin": "Minimum temperature",
}

codes = {
    "groundfrost": "frost",
    "sun": "sun",
    "tas": "tas",
    "snowLying": "snow",
    "tasmax": "tasmax",
    "hurs": "hurs",
    "rainfall": "rain",
    "sfcWind": "wind",
    "tasmin": "tasmin",
}


def get_attributes(data_array, to_drop=None):
    """
    Returns a dict describing the attributes of a DataArray.
    Optionally, filters the attributes with to_drop
    """
    assert isinstance(to_drop, list) or to_drop is None
    assert isinstance(data_array, xr.DataArray)
    attrs_dict = {}
    for key, value in data_array.attrs.items():
        if key not in to_drop:
            attrs_dict[key] = value
    attrs_dict["id"] = data_array.name
    attrs_dict["name"] = names[data_array.name]
    return attrs_dict

# %%
rows_list = []
for path in NC_FILES:
    with xr.open_dataarray(path, decode_coords="all", chunks="auto") as da:
        attrs_dict = get_attributes(
            da, to_drop=["units", "cell_methods", "level", "standard_name"]
        )
        rows_list.append(attrs_dict)
df = pd.DataFrame(rows_list)
df['label_units'] = df['label_units'].replace('C', '°C')
df['label_units'] = df['label_units'].replace('m s-1', 'm/s')
df['plot_label'] = df['plot_label'].replace('\(C\)', '(°C)', regex=True)
df['plot_label'] = df['plot_label'].replace('\(m s-1\)', '(m/s)', regex=True)
df
# Out:
#                                            long_name              description  \
# 0  Number of days with ground frost (minimum gras...   Days with ground frost
# 1                                     Sunshine hours           Sunshine hours
# 2                               Mean air temperature     Mean air temperature
# 3             Number of days with snow lying at 0900               Snow lying
# 4                            Maximum air temperature  Maximum air temperature
# 5                                  Relative humidity        Relative humidity
# 6                         Total precipitation amount           Total rainfall
# 7                                  Wind speed at 10m               Wind speed
# 8                            Minimum air temperature  Minimum air temperature
#
#   label_units                            plot_label           id  \
# 0        days                   Ground frost (days)  groundfrost
# 1           h                    Sunshine hours (h)          sun
# 2          °C     Mean air temperature at 1.5m (°C)          tas
# 3        days                     Snow lying (days)    snowLying
# 4          °C  Maximum air temperature at 1.5m (°C)       tasmax
# 5           %         Relative humidity at 1.5m (%)         hurs
# 6          mm                   Total rainfall (mm)     rainfall
# 7         m/s               Wind speed at 10m (m/s)      sfcWind
# 8          °C  Minimum air temperature at 1.5m (°C)       tasmin
#
#                   name
# 0                Frost
# 1                  Sun
# 2          Temperature
# 3                 Snow
# 4  Maximum temperature
# 5             Humidity
# 6                 Rain
# 7                 Wind
# 8  Minimum temperature

# %%
df = (
    df.rename(
        columns={
            "description": "long_name",
            "long_name": "description",
            "label_units": "units",
            "plot_label": "label",
        }
    )
    .sort_values("name")
    .reset_index(drop=True)
)

df
# Out:
#                                          description                long_name  \
# 0  Number of days with ground frost (minimum gras...   Days with ground frost
# 1                                  Relative humidity        Relative humidity
# 2                            Maximum air temperature  Maximum air temperature
# 3                            Minimum air temperature  Minimum air temperature
# 4                         Total precipitation amount           Total rainfall
# 5             Number of days with snow lying at 0900               Snow lying
# 6                                     Sunshine hours           Sunshine hours
# 7                               Mean air temperature     Mean air temperature
# 8                                  Wind speed at 10m               Wind speed
#
#   units                                 label           id  \
# 0  days                   Ground frost (days)  groundfrost
# 1     %         Relative humidity at 1.5m (%)         hurs
# 2    °C  Maximum air temperature at 1.5m (°C)       tasmax
# 3    °C  Minimum air temperature at 1.5m (°C)       tasmin
# 4    mm                   Total rainfall (mm)     rainfall
# 5  days                     Snow lying (days)    snowLying
# 6     h                    Sunshine hours (h)          sun
# 7    °C     Mean air temperature at 1.5m (°C)          tas
# 8   m/s               Wind speed at 10m (m/s)      sfcWind
#
#                   name
# 0                Frost
# 1             Humidity
# 2  Maximum temperature
# 3  Minimum temperature
# 4                 Rain
# 5                 Snow
# 6                  Sun
# 7          Temperature
# 8                 Wind

# %%
df.to_csv(os.path.join(OUT_DIR, "indicator.csv"), index=False)
